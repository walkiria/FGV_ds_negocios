# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
answers = pd.read_csv('archive/Answers.csv', encoding='latin-1')
questions = pd.read_csv('archive/Questions.csv', encoding='latin-1')
tags =  pd.read_csv('archive/Tags.csv', encoding='latin-1')

# %%
answers.head()
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0   92         61.0  2008-08-01T14:45:37Z        90     13
# 1  124         26.0  2008-08-01T16:09:47Z        80     12
# 2  199         50.0  2008-08-01T19:36:46Z       180      1
# 3  269         91.0  2008-08-01T23:49:57Z       260      4
# 4  307         49.0  2008-08-02T01:49:46Z       260     28
#
#                                                 Body
# 0  <p><a href="http://svnbook.red-bean.com/">Vers...
# 1  <p>I wound up using this. It is a kind of a ha...
# 2  <p>I've read somewhere the human eye can't dis...
# 3  <p>Yes, I thought about that, but I soon figur...
# 4  <p><a href="http://www.codeproject.com/Article...

# %%
questions.head()
# Out:
#     Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1   90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2  120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3  180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4  260         91.0  2008-08-01T23:22:08Z                   NaN     49
#
#                                                Title  \
# 0  SQLStatement.execute() - multiple queries in o...
# 1  Good branching and merging tutorials for Torto...
# 2                                  ASP.NET Site Maps
# 3                 Function for creating color wheels
# 4  Adding scripting functionality to .NET applica...
#
#                                                 Body
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# ...

# %%
questions_sample = questions.sample(frac=0.3, replace=False, random_state=1)

# %%
questions_sample = questions_sample.reset_index()

# %%
questions.shape
# Out:
# (1264216, 7)

# %%
questions_sample.shape
# Out:
# (379265, 7)

# %%
answers_questions = pd.merge(questions_sample, answers, how='inner', left_on='Id', right_on='ParentId')

# %%
answers_questions.head()
# Out:
#      index      Id_x  OwnerUserId_x        CreationDate_x  \
# 0   345874  12395950       795000.0  2012-09-12T20:45:35Z
# 1   654403  22426350      1378959.0  2014-03-15T16:17:17Z
# 2   574386  19842160      2429569.0  2013-11-07T17:07:34Z
# 3   671187  22953000      3513576.0  2014-04-09T04:48:04Z
# 4  1088725  35528560      1712334.0  2016-02-20T20:24:29Z
#
#              ClosedDate  Score_x  \
# 0  2016-10-05T20:53:44Z        2
# 1                   NaN        0
# 2                   NaN        0
# 3                   NaN        0
# 4                   NaN        0
#
#                                                Title  \
# 0       Calling Twain driver from 64 bit application
# 1  Why does variable in struct instance change af...
# 2  dynamically creating text fields lands up in d...
# 3      Javascript in PHP/HTML hiding Div not working
# 4  Design a compareTo that can sort in ascending ...
#
#                                               Body_x      Id_y  OwnerUserId_y  \
# ...

# %%
answers_questions.shape
# Out:
# (604046, 14)

# %%
answers_sample = answers_questions[['Id_y', 'OwnerUserId_y','CreationDate_y', 'ParentId', 'Score_y', 'Body_y' ]]

# %%
answers_sample.columns = ['Id', 'OwnerUserId','CreationDate', 'ParentId', 'Score', 'Body' ]

# %%
answers_sample.sort_values(by='ParentId')
# Out:
#               Id  OwnerUserId          CreationDate  ParentId  Score  \
# 394751     10008       1109.0  2008-08-13T16:09:09Z        80      6
# 394752   3770976     364174.0  2010-09-22T15:37:30Z        80      1
# 394750       124         26.0  2008-08-01T16:09:47Z        80     12
# 54524      59760       5845.0  2008-09-12T19:00:13Z       180     17
# 54527    1499720     115432.0  2009-09-30T18:00:26Z       180      0
# ...          ...          ...                   ...       ...    ...
# 383221  40142857    4228492.0  2016-10-19T23:00:25Z  40142450      0
# 296519  40142627    6820506.0  2016-10-19T22:36:26Z  40142470      0
# 296520  40142630    4162641.0  2016-10-19T22:36:43Z  40142470      1
# 417346  40143212    1491895.0  2016-10-19T23:38:17Z  40143190      5
# 417347  40143247     333403.0  2016-10-19T23:42:35Z  40143190      0
#
#                                                      Body
# 394751  <p>The <a href="http://en.wikipedia.org/wiki/S...
# ...

# %%
answers_sample.to_csv('answers_sample.csv')

# %%
questions_sample.to_csv('questions_sample.csv')
