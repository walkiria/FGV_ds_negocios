# %%
import os

import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
main_path = '/Users/henriquevieira/Documents/escola_blue/materiais/Aula 4/'

# %%
def getImage(path):
    return OffsetImage(plt.imread(path))

# %%
dados = pd.read_csv(os.path.join(main_path, 'exemplo_peso_altura_animais_fazenda.csv'), 
                    delimiter=';')
dados
# Out:
#     peso  altura
# 0    2.4    0.80
# 1  102.0    0.70
# 2  430.0    1.50
# 3  306.0    1.57
# 4    2.9    0.73
# 5  131.0    0.85
# 6  280.0    1.40
# 7  318.0    1.60
# 8  110.0    0.80

# %%
paths = [
    os.path.join(main_path, 'icones', 'hen_64x64.png'),
    os.path.join(main_path, 'icones', 'pig_64x64.png'),
    os.path.join(main_path, 'icones', 'cow_64x64.png'),
    os.path.join(main_path, 'icones', 'horse_64x64.png'),
    os.path.join(main_path, 'icones', 'hen_64x64.png'),
    os.path.join(main_path, 'icones', 'pig_64x64.png'),
    os.path.join(main_path, 'icones', 'horse_64x64.png'),
    os.path.join(main_path, 'icones', 'horse_64x64.png'),
    os.path.join(main_path, 'icones', 'pig_64x64.png')]

# %%
x = dados.peso.tolist()
y = dados.altura.tolist()

# %%
sns.set_style('darkgrid')

plt.figure(figsize=[8,8])
ax = sns.scatterplot(x='peso', y='altura', s = 200,
                     data=dados,
                     palette="deep")
ax.set_title('ANIMAIS DA FAZENDA', loc='left', fontsize=18)
ax.set_xlabel('ALTURA', fontsize=14)
ax.set_ylabel('PESO', fontsize=14)

plt.savefig(os.path.join(main_path, 'scatterplot_animais_fazenda1.png'))

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize = [8,8])
ax.scatter(x, y)
ax.set_title('ANIMAIS DA FAZENDA', loc='left', fontsize=18)
ax.set_xlabel('ALTURA', fontsize=14)
ax.set_ylabel('PESO', fontsize=14)

for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)
    
plt.savefig(os.path.join(main_path, 'scatterplot_animais_fazenda2.png'))
